# %%
import matplotlib.pyplot as plt
import pickle

# %%
with open('logs/res.pkl', 'rb') as f:
    res = pickle.load(f)

# %%
plt.xticks = ([0, 1, 2, 3, 4])
plt.plot([res[key] for key in res])
plt.show()
    # plt.plot(res[key], label=key)
# plt.legend()
